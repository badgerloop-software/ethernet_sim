# %%
import gpxpy
import pandas as pd
gpx_path = 'pow_day_at_vail.gpx'
with open(gpx_path) as f:
    gpx = gpxpy.parse(f)

# Convert to a dataframe one point at a time.
points = []
for segment in gpx.tracks[0].segments:
    for p in segment.points:
        points.append({
            'time': p.time,
            'latitude': p.latitude,
            'longitude': p.longitude,
            'elevation': p.elevation,
        })
df = pd.DataFrame.from_records(points)

# %%
df
# Out:
#                            time   latitude   longitude  elevation
# 0     2024-01-06 17:10:15+00:00  39.621451 -106.369849     2932.8
# 1     2024-01-06 17:10:16+00:00  39.621401 -106.369840     2933.9
# 2     2024-01-06 17:10:17+00:00  39.621358 -106.369833     2934.9
# 3     2024-01-06 17:10:18+00:00  39.621318 -106.369819     2935.8
# 4     2024-01-06 17:10:19+00:00  39.621289 -106.369819     2936.4
# ...                         ...        ...         ...        ...
# 21428 2024-01-06 23:08:47+00:00  39.639172 -106.373849     2500.7
# 21429 2024-01-06 23:08:48+00:00  39.639176 -106.373843     2500.6
# 21430 2024-01-06 23:08:49+00:00  39.639171 -106.373854     2500.7
# 21431 2024-01-06 23:08:50+00:00  39.639162 -106.373849     2500.7
# 21432 2024-01-06 23:08:51+00:00  39.639161 -106.373855     2500.7
#
# [21433 rows x 4 columns]

# %%
df['time']=pd.to_datetime(df['time']).map(pd.Timestamp.timestamp).astype(int)

# %%
df
# Out:
#              time   latitude   longitude  elevation
# 0      1704561015  39.621451 -106.369849     2932.8
# 1      1704561016  39.621401 -106.369840     2933.9
# 2      1704561017  39.621358 -106.369833     2934.9
# 3      1704561018  39.621318 -106.369819     2935.8
# 4      1704561019  39.621289 -106.369819     2936.4
# ...           ...        ...         ...        ...
# 21428  1704582527  39.639172 -106.373849     2500.7
# 21429  1704582528  39.639176 -106.373843     2500.6
# 21430  1704582529  39.639171 -106.373854     2500.7
# 21431  1704582530  39.639162 -106.373849     2500.7
# 21432  1704582531  39.639161 -106.373855     2500.7
#
# [21433 rows x 4 columns]

# %%
df.to_csv("file.csv", encoding='utf-8', index=False)

# %%
points
# Out:
# [{'time': datetime.datetime(2024, 1, 6, 17, 10, 15, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.621451,
#   'longitude': -106.369849,
#   'elevation': 2932.8},
#  {'time': datetime.datetime(2024, 1, 6, 17, 10, 16, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.621401,
#   'longitude': -106.36984,
#   'elevation': 2933.9},
#  {'time': datetime.datetime(2024, 1, 6, 17, 10, 17, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.621358,
#   'longitude': -106.369833,
#   'elevation': 2934.9},
#  {'time': datetime.datetime(2024, 1, 6, 17, 10, 18, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.621318,
#   'longitude': -106.369819,
#   'elevation': 2935.8},
#  {'time': datetime.datetime(2024, 1, 6, 17, 10, 19, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.621289,
#   'longitude': -106.369819,
#   'elevation': 2936.4},
#  {'time': datetime.datetime(2024, 1, 6, 17, 10, 20, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.621254,
#   'longitude': -106.369806,
#   'elevation': 2937.2},
#  {'time': datetime.datetime(2024, 1, 6, 17, 10, 21, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.621241,
#   'longitude': -106.369803,
#   'elevation': 2937.5},
#  {'time': datetime.datetime(2024, 1, 6, 17, 10, 22, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.621222,
#   'longitude': -106.369795,
#   'elevation': 2937.9},
#  {'time': datetime.datetime(2024, 1, 6, 17, 10, 23, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.621214,
#   'longitude': -106.36979,
#   'elevation': 2938.1},
#  {'time': datetime.datetime(2024, 1, 6, 17, 10, 24, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.621206,
#   'longitude': -106.369786,
#   'elevation': 2938.3},
#  {'time': datetime.datetime(2024, 1, 6, 17, 10, 25, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.621192,
#   'longitude': -106.369792,
#   'elevation': 2938.6},
#  {'time': datetime.datetime(2024, 1, 6, 17, 10, 26, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.621185,
#   'longitude': -106.36979,
#   'elevation': 2938.8},
#  {'time': datetime.datetime(2024, 1, 6, 17, 10, 27, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.621177,
#   'longitude': -106.369788,
#   'elevation': 2939.0},
#  {'time': datetime.datetime(2024, 1, 6, 17, 10, 28, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.621169,
#   'longitude': -106.369787,
#   'elevation': 2939.1},
#  {'time': datetime.datetime(2024, 1, 6, 17, 10, 29, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.621155,
#   'longitude': -106.369787,
#   'elevation': 2939.4},
#  {'time': datetime.datetime(2024, 1, 6, 17, 10, 30, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.62114,
#   'longitude': -106.369786,
#   'elevation': 2939.8},
#  {'time': datetime.datetime(2024, 1, 6, 17, 10, 31, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.621109,
#   'longitude': -106.369768,
#   'elevation': 2940.5},
#  {'time': datetime.datetime(2024, 1, 6, 17, 10, 32, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.621079,
#   'longitude': -106.369766,
#   'elevation': 2941.2},
#  {'time': datetime.datetime(2024, 1, 6, 17, 10, 33, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.621068,
#   'longitude': -106.369772,
#   'elevation': 2941.5},
#  {'time': datetime.datetime(2024, 1, 6, 17, 10, 34, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.621052,
#   'longitude': -106.36976,
#   'elevation': 2941.9},
#  {'time': datetime.datetime(2024, 1, 6, 17, 10, 35, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.621036,
#   'longitude': -106.369751,
#   'elevation': 2942.3},
#  {'time': datetime.datetime(2024, 1, 6, 17, 10, 36, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.620996,
#   'longitude': -106.369732,
#   'elevation': 2943.3},
#  {'time': datetime.datetime(2024, 1, 6, 17, 10, 37, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.620981,
#   'longitude': -106.369725,
#   'elevation': 2943.6},
#  {'time': datetime.datetime(2024, 1, 6, 17, 10, 38, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.620947,
#   'longitude': -106.369725,
#   'elevation': 2944.4},
#  {'time': datetime.datetime(2024, 1, 6, 17, 10, 39, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.620932,
#   'longitude': -106.369723,
#   'elevation': 2944.8},
#  {'time': datetime.datetime(2024, 1, 6, 17, 10, 40, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.620892,
#   'longitude': -106.369713,
#   'elevation': 2945.7},
#  {'time': datetime.datetime(2024, 1, 6, 17, 10, 41, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.620879,
#   'longitude': -106.36971,
#   'elevation': 2946.1},
#  {'time': datetime.datetime(2024, 1, 6, 17, 10, 42, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.620851,
#   'longitude': -106.369707,
#   'elevation': 2946.7},
#  {'time': datetime.datetime(2024, 1, 6, 17, 10, 43, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.620823,
#   'longitude': -106.369704,
#   'elevation': 2947.4},
#  {'time': datetime.datetime(2024, 1, 6, 17, 10, 44, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.620784,
#   'longitude': -106.369691,
#   'elevation': 2948.4},
#  {'time': datetime.datetime(2024, 1, 6, 17, 10, 45, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.620748,
#   'longitude': -106.369687,
#   'elevation': 2949.3},
#  {'time': datetime.datetime(2024, 1, 6, 17, 10, 46, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.620713,
#   'longitude': -106.369689,
#   'elevation': 2950.1},
#  {'time': datetime.datetime(2024, 1, 6, 17, 10, 47, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.62066,
#   'longitude': -106.36965,
#   'elevation': 2951.7},
#  {'time': datetime.datetime(2024, 1, 6, 17, 10, 48, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.620615,
#   'longitude': -106.369652,
#   'elevation': 2952.8},
#  {'time': datetime.datetime(2024, 1, 6, 17, 10, 49, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.620578,
#   'longitude': -106.369651,
#   'elevation': 2953.8},
#  {'time': datetime.datetime(2024, 1, 6, 17, 10, 50, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.620537,
#   'longitude': -106.369645,
#   'elevation': 2954.8},
#  {'time': datetime.datetime(2024, 1, 6, 17, 10, 51, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.620488,
#   'longitude': -106.369642,
#   'elevation': 2956.1},
#  {'time': datetime.datetime(2024, 1, 6, 17, 10, 52, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.620445,
#   'longitude': -106.369641,
#   'elevation': 2957.2},
#  {'time': datetime.datetime(2024, 1, 6, 17, 10, 53, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.6204,
#   'longitude': -106.369628,
#   'elevation': 2958.4},
#  {'time': datetime.datetime(2024, 1, 6, 17, 10, 54, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.620364,
#   'longitude': -106.369606,
#   'elevation': 2959.4},
#  {'time': datetime.datetime(2024, 1, 6, 17, 10, 55, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.62031,
#   'longitude': -106.369591,
#   'elevation': 2961.0},
#  {'time': datetime.datetime(2024, 1, 6, 17, 10, 56, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.620254,
#   'longitude': -106.369582,
#   'elevation': 2962.6},
#  {'time': datetime.datetime(2024, 1, 6, 17, 10, 57, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.620207,
#   'longitude': -106.369571,
#   'elevation': 2964.1},
#  {'time': datetime.datetime(2024, 1, 6, 17, 10, 58, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.62016,
#   'longitude': -106.369572,
#   'elevation': 2965.6},
#  {'time': datetime.datetime(2024, 1, 6, 17, 10, 59, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.620112,
#   'longitude': -106.369562,
#   'elevation': 2967.1},
#  {'time': datetime.datetime(2024, 1, 6, 17, 11, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.620063,
#   'longitude': -106.369546,
#   'elevation': 2968.7},
#  {'time': datetime.datetime(2024, 1, 6, 17, 11, 1, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.620012,
#   'longitude': -106.369534,
#   'elevation': 2970.3},
#  {'time': datetime.datetime(2024, 1, 6, 17, 11, 2, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.619962,
#   'longitude': -106.369531,
#   'elevation': 2971.8},
#  {'time': datetime.datetime(2024, 1, 6, 17, 11, 3, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.619916,
#   'longitude': -106.369515,
#   'elevation': 2973.2},
#  {'time': datetime.datetime(2024, 1, 6, 17, 11, 4, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.619869,
#   'longitude': -106.36951,
#   'elevation': 2974.5},
#  {'time': datetime.datetime(2024, 1, 6, 17, 11, 5, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.619814,
#   'longitude': -106.369495,
#   'elevation': 2976.0},
#  {'time': datetime.datetime(2024, 1, 6, 17, 11, 6, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.619758,
#   'longitude': -106.36948,
#   'elevation': 2977.5},
#  {'time': datetime.datetime(2024, 1, 6, 17, 11, 7, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.619705,
#   'longitude': -106.369469,
#   'elevation': 2978.8},
#  {'time': datetime.datetime(2024, 1, 6, 17, 11, 8, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.61966,
#   'longitude': -106.369459,
#   'elevation': 2979.9},
#  {'time': datetime.datetime(2024, 1, 6, 17, 11, 9, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.619604,
#   'longitude': -106.369447,
#   'elevation': 2981.3},
#  {'time': datetime.datetime(2024, 1, 6, 17, 11, 10, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.61955,
#   'longitude': -106.369434,
#   'elevation': 2982.7},
#  {'time': datetime.datetime(2024, 1, 6, 17, 11, 11, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.619502,
#   'longitude': -106.369425,
#   'elevation': 2983.9},
#  {'time': datetime.datetime(2024, 1, 6, 17, 11, 12, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.619451,
#   'longitude': -106.369414,
#   'elevation': 2985.2},
#  {'time': datetime.datetime(2024, 1, 6, 17, 11, 13, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.619395,
#   'longitude': -106.369402,
#   'elevation': 2986.6},
#  {'time': datetime.datetime(2024, 1, 6, 17, 11, 14, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.61935,
#   'longitude': -106.369393,
#   'elevation': 2987.8},
#  {'time': datetime.datetime(2024, 1, 6, 17, 11, 15, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.619301,
#   'longitude': -106.369391,
#   'elevation': 2989.0},
#  {'time': datetime.datetime(2024, 1, 6, 17, 11, 16, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.61925,
#   'longitude': -106.369379,
#   'elevation': 2990.3},
#  {'time': datetime.datetime(2024, 1, 6, 17, 11, 17, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.619205,
#   'longitude': -106.369372,
#   'elevation': 2991.5},
#  {'time': datetime.datetime(2024, 1, 6, 17, 11, 18, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.619153,
#   'longitude': -106.369357,
#   'elevation': 2992.9},
#  {'time': datetime.datetime(2024, 1, 6, 17, 11, 19, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.619106,
#   'longitude': -106.369345,
#   'elevation': 2994.2},
#  {'time': datetime.datetime(2024, 1, 6, 17, 11, 20, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.619057,
#   'longitude': -106.369338,
#   'elevation': 2995.5},
#  {'time': datetime.datetime(2024, 1, 6, 17, 11, 21, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.619007,
#   'longitude': -106.369333,
#   'elevation': 2996.9},
#  {'time': datetime.datetime(2024, 1, 6, 17, 11, 22, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.61896,
#   'longitude': -106.369312,
#   'elevation': 2998.2},
#  {'time': datetime.datetime(2024, 1, 6, 17, 11, 23, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.618914,
#   'longitude': -106.369311,
#   'elevation': 2999.5},
#  {'time': datetime.datetime(2024, 1, 6, 17, 11, 24, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.618868,
#   'longitude': -106.3693,
#   'elevation': 3000.8},
#  {'time': datetime.datetime(2024, 1, 6, 17, 11, 25, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.618819,
#   'longitude': -106.36929,
#   'elevation': 3002.2},
#  {'time': datetime.datetime(2024, 1, 6, 17, 11, 26, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.618771,
#   'longitude': -106.369281,
#   'elevation': 3003.5},
#  {'time': datetime.datetime(2024, 1, 6, 17, 11, 27, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.618721,
#   'longitude': -106.369277,
#   'elevation': 3004.9},
#  {'time': datetime.datetime(2024, 1, 6, 17, 11, 28, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.618674,
#   'longitude': -106.369268,
#   'elevation': 3006.2},
#  {'time': datetime.datetime(2024, 1, 6, 17, 11, 29, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.61862,
#   'longitude': -106.369259,
#   'elevation': 3007.7},
#  {'time': datetime.datetime(2024, 1, 6, 17, 11, 30, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.618568,
#   'longitude': -106.369245,
#   'elevation': 3009.3},
#  {'time': datetime.datetime(2024, 1, 6, 17, 11, 31, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.618515,
#   'longitude': -106.369238,
#   'elevation': 3010.9},
#  {'time': datetime.datetime(2024, 1, 6, 17, 11, 32, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.61847,
#   'longitude': -106.369224,
#   'elevation': 3012.4},
#  {'time': datetime.datetime(2024, 1, 6, 17, 11, 33, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.618423,
#   'longitude': -106.369208,
#   'elevation': 3014.0},
#  {'time': datetime.datetime(2024, 1, 6, 17, 11, 34, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.618379,
#   'longitude': -106.369195,
#   'elevation': 3015.4},
#  {'time': datetime.datetime(2024, 1, 6, 17, 11, 35, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.618331,
#   'longitude': -106.369188,
#   'elevation': 3017.0},
#  {'time': datetime.datetime(2024, 1, 6, 17, 11, 36, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.618283,
#   'longitude': -106.369179,
#   'elevation': 3018.6},
#  {'time': datetime.datetime(2024, 1, 6, 17, 11, 37, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.618239,
#   'longitude': -106.369172,
#   'elevation': 3020.0},
#  {'time': datetime.datetime(2024, 1, 6, 17, 11, 38, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.618193,
#   'longitude': -106.369164,
#   'elevation': 3021.5},
#  {'time': datetime.datetime(2024, 1, 6, 17, 11, 39, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.618146,
#   'longitude': -106.369154,
#   'elevation': 3022.9},
#  {'time': datetime.datetime(2024, 1, 6, 17, 11, 40, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.618088,
#   'longitude': -106.369141,
#   'elevation': 3024.6},
#  {'time': datetime.datetime(2024, 1, 6, 17, 11, 41, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.618039,
#   'longitude': -106.369129,
#   'elevation': 3026.0},
#  {'time': datetime.datetime(2024, 1, 6, 17, 11, 42, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.617994,
#   'longitude': -106.369121,
#   'elevation': 3027.3},
#  {'time': datetime.datetime(2024, 1, 6, 17, 11, 43, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.617942,
#   'longitude': -106.369112,
#   'elevation': 3028.8},
#  {'time': datetime.datetime(2024, 1, 6, 17, 11, 44, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.617892,
#   'longitude': -106.369099,
#   'elevation': 3030.3},
#  {'time': datetime.datetime(2024, 1, 6, 17, 11, 45, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.617844,
#   'longitude': -106.369091,
#   'elevation': 3031.7},
#  {'time': datetime.datetime(2024, 1, 6, 17, 11, 46, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.6178,
#   'longitude': -106.369078,
#   'elevation': 3033.0},
#  {'time': datetime.datetime(2024, 1, 6, 17, 11, 47, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.61775,
#   'longitude': -106.369077,
#   'elevation': 3034.6},
#  {'time': datetime.datetime(2024, 1, 6, 17, 11, 48, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.617703,
#   'longitude': -106.369065,
#   'elevation': 3036.1},
#  {'time': datetime.datetime(2024, 1, 6, 17, 11, 49, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.617652,
#   'longitude': -106.369048,
#   'elevation': 3037.7},
#  {'time': datetime.datetime(2024, 1, 6, 17, 11, 50, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.617605,
#   'longitude': -106.369039,
#   'elevation': 3039.2},
#  {'time': datetime.datetime(2024, 1, 6, 17, 11, 51, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.617554,
#   'longitude': -106.369036,
#   'elevation': 3040.9},
#  {'time': datetime.datetime(2024, 1, 6, 17, 11, 52, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.61751,
#   'longitude': -106.369029,
#   'elevation': 3042.3},
#  {'time': datetime.datetime(2024, 1, 6, 17, 11, 53, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.61746,
#   'longitude': -106.369017,
#   'elevation': 3043.9},
#  {'time': datetime.datetime(2024, 1, 6, 17, 11, 54, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.617415,
#   'longitude': -106.369009,
#   'elevation': 3045.3},
#  {'time': datetime.datetime(2024, 1, 6, 17, 11, 55, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.617365,
#   'longitude': -106.369001,
#   'elevation': 3046.9},
#  {'time': datetime.datetime(2024, 1, 6, 17, 11, 56, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.617315,
#   'longitude': -106.36899,
#   'elevation': 3048.4},
#  {'time': datetime.datetime(2024, 1, 6, 17, 11, 57, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.617262,
#   'longitude': -106.368976,
#   'elevation': 3050.0},
#  {'time': datetime.datetime(2024, 1, 6, 17, 11, 58, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.61722,
#   'longitude': -106.36896,
#   'elevation': 3051.3},
#  {'time': datetime.datetime(2024, 1, 6, 17, 11, 59, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.617187,
#   'longitude': -106.368959,
#   'elevation': 3052.2},
#  {'time': datetime.datetime(2024, 1, 6, 17, 12, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.617129,
#   'longitude': -106.368947,
#   'elevation': 3053.9},
#  {'time': datetime.datetime(2024, 1, 6, 17, 12, 1, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.617079,
#   'longitude': -106.368928,
#   'elevation': 3055.4},
#  {'time': datetime.datetime(2024, 1, 6, 17, 12, 2, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.61703,
#   'longitude': -106.368916,
#   'elevation': 3056.9},
#  {'time': datetime.datetime(2024, 1, 6, 17, 12, 3, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.616981,
#   'longitude': -106.36891,
#   'elevation': 3058.3},
#  {'time': datetime.datetime(2024, 1, 6, 17, 12, 4, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.616927,
#   'longitude': -106.368914,
#   'elevation': 3059.9},
#  {'time': datetime.datetime(2024, 1, 6, 17, 12, 5, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.616876,
#   'longitude': -106.368911,
#   'elevation': 3061.4},
#  {'time': datetime.datetime(2024, 1, 6, 17, 12, 6, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.616829,
#   'longitude': -106.368894,
#   'elevation': 3062.8},
#  {'time': datetime.datetime(2024, 1, 6, 17, 12, 7, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.616778,
#   'longitude': -106.368884,
#   'elevation': 3064.2},
#  {'time': datetime.datetime(2024, 1, 6, 17, 12, 8, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.616734,
#   'longitude': -106.368874,
#   'elevation': 3065.5},
#  {'time': datetime.datetime(2024, 1, 6, 17, 12, 9, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.616685,
#   'longitude': -106.368866,
#   'elevation': 3066.9},
#  {'time': datetime.datetime(2024, 1, 6, 17, 12, 10, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.616635,
#   'longitude': -106.368855,
#   'elevation': 3068.3},
#  {'time': datetime.datetime(2024, 1, 6, 17, 12, 11, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.61659,
#   'longitude': -106.368847,
#   'elevation': 3069.4},
#  {'time': datetime.datetime(2024, 1, 6, 17, 12, 12, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.616538,
#   'longitude': -106.368837,
#   'elevation': 3070.6},
#  {'time': datetime.datetime(2024, 1, 6, 17, 12, 13, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.616491,
#   'longitude': -106.368828,
#   'elevation': 3071.7},
#  {'time': datetime.datetime(2024, 1, 6, 17, 12, 14, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.616441,
#   'longitude': -106.368817,
#   'elevation': 3072.7},
#  {'time': datetime.datetime(2024, 1, 6, 17, 12, 15, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.61639,
#   'longitude': -106.368807,
#   'elevation': 3073.7},
#  {'time': datetime.datetime(2024, 1, 6, 17, 12, 16, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.616341,
#   'longitude': -106.368799,
#   'elevation': 3074.6},
#  {'time': datetime.datetime(2024, 1, 6, 17, 12, 17, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.616292,
#   'longitude': -106.36879,
#   'elevation': 3075.4},
#  {'time': datetime.datetime(2024, 1, 6, 17, 12, 18, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.616243,
#   'longitude': -106.368774,
#   'elevation': 3076.2},
#  {'time': datetime.datetime(2024, 1, 6, 17, 12, 19, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.616198,
#   'longitude': -106.368767,
#   'elevation': 3076.9},
#  {'time': datetime.datetime(2024, 1, 6, 17, 12, 21, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.616097,
#   'longitude': -106.368753,
#   'elevation': 3078.4},
#  {'time': datetime.datetime(2024, 1, 6, 17, 12, 22, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.616047,
#   'longitude': -106.368737,
#   'elevation': 3079.1},
#  {'time': datetime.datetime(2024, 1, 6, 17, 12, 23, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.615994,
#   'longitude': -106.368722,
#   'elevation': 3079.9},
#  {'time': datetime.datetime(2024, 1, 6, 17, 12, 24, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.615943,
#   'longitude': -106.368714,
#   'elevation': 3080.7},
#  {'time': datetime.datetime(2024, 1, 6, 17, 12, 25, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.615894,
#   'longitude': -106.368711,
#   'elevation': 3081.4},
#  {'time': datetime.datetime(2024, 1, 6, 17, 12, 26, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.615843,
#   'longitude': -106.3687,
#   'elevation': 3082.2},
#  {'time': datetime.datetime(2024, 1, 6, 17, 12, 27, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.615792,
#   'longitude': -106.368686,
#   'elevation': 3083.0},
#  {'time': datetime.datetime(2024, 1, 6, 17, 12, 28, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.615747,
#   'longitude': -106.368682,
#   'elevation': 3083.7},
#  {'time': datetime.datetime(2024, 1, 6, 17, 12, 29, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.615701,
#   'longitude': -106.368669,
#   'elevation': 3084.4},
#  {'time': datetime.datetime(2024, 1, 6, 17, 12, 30, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.615651,
#   'longitude': -106.368657,
#   'elevation': 3085.3},
#  {'time': datetime.datetime(2024, 1, 6, 17, 12, 31, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.615599,
#   'longitude': -106.368644,
#   'elevation': 3086.1},
#  {'time': datetime.datetime(2024, 1, 6, 17, 12, 32, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.615548,
#   'longitude': -106.368631,
#   'elevation': 3087.0},
#  {'time': datetime.datetime(2024, 1, 6, 17, 12, 33, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.615496,
#   'longitude': -106.368618,
#   'elevation': 3087.8},
#  {'time': datetime.datetime(2024, 1, 6, 17, 12, 34, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.615437,
#   'longitude': -106.368605,
#   'elevation': 3088.7},
#  {'time': datetime.datetime(2024, 1, 6, 17, 12, 35, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.61539,
#   'longitude': -106.36859,
#   'elevation': 3089.5},
#  {'time': datetime.datetime(2024, 1, 6, 17, 12, 36, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.615341,
#   'longitude': -106.368581,
#   'elevation': 3090.2},
#  {'time': datetime.datetime(2024, 1, 6, 17, 12, 37, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.615289,
#   'longitude': -106.368568,
#   'elevation': 3090.9},
#  {'time': datetime.datetime(2024, 1, 6, 17, 12, 38, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.615242,
#   'longitude': -106.368553,
#   'elevation': 3091.6},
#  {'time': datetime.datetime(2024, 1, 6, 17, 12, 39, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.615194,
#   'longitude': -106.368541,
#   'elevation': 3092.2},
#  {'time': datetime.datetime(2024, 1, 6, 17, 12, 40, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.615143,
#   'longitude': -106.368532,
#   'elevation': 3092.9},
#  {'time': datetime.datetime(2024, 1, 6, 17, 12, 41, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.615092,
#   'longitude': -106.368529,
#   'elevation': 3093.5},
#  {'time': datetime.datetime(2024, 1, 6, 17, 12, 42, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.615043,
#   'longitude': -106.368519,
#   'elevation': 3094.2},
#  {'time': datetime.datetime(2024, 1, 6, 17, 12, 43, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614992,
#   'longitude': -106.368515,
#   'elevation': 3094.8},
#  {'time': datetime.datetime(2024, 1, 6, 17, 12, 44, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614941,
#   'longitude': -106.368509,
#   'elevation': 3095.5},
#  {'time': datetime.datetime(2024, 1, 6, 17, 12, 45, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.61489,
#   'longitude': -106.368495,
#   'elevation': 3096.2},
#  {'time': datetime.datetime(2024, 1, 6, 17, 12, 46, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614837,
#   'longitude': -106.368484,
#   'elevation': 3096.9},
#  {'time': datetime.datetime(2024, 1, 6, 17, 12, 47, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614786,
#   'longitude': -106.368475,
#   'elevation': 3097.6},
#  {'time': datetime.datetime(2024, 1, 6, 17, 12, 48, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614733,
#   'longitude': -106.368462,
#   'elevation': 3098.3},
#  {'time': datetime.datetime(2024, 1, 6, 17, 12, 49, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614703,
#   'longitude': -106.368455,
#   'elevation': 3098.6},
#  {'time': datetime.datetime(2024, 1, 6, 17, 12, 50, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614682,
#   'longitude': -106.368458,
#   'elevation': 3098.6},
#  {'time': datetime.datetime(2024, 1, 6, 17, 12, 51, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614679,
#   'longitude': -106.368463,
#   'elevation': 3099.2},
#  {'time': datetime.datetime(2024, 1, 6, 17, 12, 52, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614671,
#   'longitude': -106.368464,
#   'elevation': 3099.2},
#  {'time': datetime.datetime(2024, 1, 6, 17, 12, 53, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614672,
#   'longitude': -106.368481,
#   'elevation': 3099.8},
#  {'time': datetime.datetime(2024, 1, 6, 17, 12, 54, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614659,
#   'longitude': -106.368485,
#   'elevation': 3099.8},
#  {'time': datetime.datetime(2024, 1, 6, 17, 12, 55, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614654,
#   'longitude': -106.368482,
#   'elevation': 3099.8},
#  {'time': datetime.datetime(2024, 1, 6, 17, 12, 56, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614655,
#   'longitude': -106.368473,
#   'elevation': 3099.8},
#  {'time': datetime.datetime(2024, 1, 6, 17, 12, 57, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614654,
#   'longitude': -106.368486,
#   'elevation': 3099.8},
#  {'time': datetime.datetime(2024, 1, 6, 17, 12, 58, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614658,
#   'longitude': -106.368489,
#   'elevation': 3099.8},
#  {'time': datetime.datetime(2024, 1, 6, 17, 12, 59, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614657,
#   'longitude': -106.368496,
#   'elevation': 3099.8},
#  {'time': datetime.datetime(2024, 1, 6, 17, 13, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614643,
#   'longitude': -106.368503,
#   'elevation': 3100.3},
#  {'time': datetime.datetime(2024, 1, 6, 17, 13, 1, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614639,
#   'longitude': -106.368506,
#   'elevation': 3100.3},
#  {'time': datetime.datetime(2024, 1, 6, 17, 13, 2, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614635,
#   'longitude': -106.368509,
#   'elevation': 3100.3},
#  {'time': datetime.datetime(2024, 1, 6, 17, 13, 3, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614631,
#   'longitude': -106.368512,
#   'elevation': 3100.3},
#  {'time': datetime.datetime(2024, 1, 6, 17, 13, 4, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614627,
#   'longitude': -106.368515,
#   'elevation': 3100.9},
#  {'time': datetime.datetime(2024, 1, 6, 17, 13, 5, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614623,
#   'longitude': -106.368518,
#   'elevation': 3100.9},
#  {'time': datetime.datetime(2024, 1, 6, 17, 13, 6, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614619,
#   'longitude': -106.36852,
#   'elevation': 3100.9},
#  {'time': datetime.datetime(2024, 1, 6, 17, 13, 7, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614615,
#   'longitude': -106.368523,
#   'elevation': 3100.9},
#  {'time': datetime.datetime(2024, 1, 6, 17, 13, 8, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614598,
#   'longitude': -106.368509,
#   'elevation': 3100.9},
#  {'time': datetime.datetime(2024, 1, 6, 17, 13, 9, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614585,
#   'longitude': -106.368501,
#   'elevation': 3100.9},
#  {'time': datetime.datetime(2024, 1, 6, 17, 13, 10, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614561,
#   'longitude': -106.368492,
#   'elevation': 3101.5},
#  {'time': datetime.datetime(2024, 1, 6, 17, 13, 11, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614555,
#   'longitude': -106.368483,
#   'elevation': 3101.5},
#  {'time': datetime.datetime(2024, 1, 6, 17, 13, 12, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614548,
#   'longitude': -106.368475,
#   'elevation': 3102.2},
#  {'time': datetime.datetime(2024, 1, 6, 17, 13, 13, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614537,
#   'longitude': -106.368464,
#   'elevation': 3101.5},
#  {'time': datetime.datetime(2024, 1, 6, 17, 13, 14, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614535,
#   'longitude': -106.368452,
#   'elevation': 3101.5},
#  {'time': datetime.datetime(2024, 1, 6, 17, 13, 15, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614531,
#   'longitude': -106.368436,
#   'elevation': 3101.5},
#  {'time': datetime.datetime(2024, 1, 6, 17, 13, 16, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614529,
#   'longitude': -106.368407,
#   'elevation': 3100.8},
#  {'time': datetime.datetime(2024, 1, 6, 17, 13, 17, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614527,
#   'longitude': -106.368396,
#   'elevation': 3100.8},
#  {'time': datetime.datetime(2024, 1, 6, 17, 13, 18, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614525,
#   'longitude': -106.368386,
#   'elevation': 3100.8},
#  {'time': datetime.datetime(2024, 1, 6, 17, 13, 19, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614528,
#   'longitude': -106.368364,
#   'elevation': 3100.1},
#  {'time': datetime.datetime(2024, 1, 6, 17, 13, 20, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614526,
#   'longitude': -106.368353,
#   'elevation': 3100.1},
#  {'time': datetime.datetime(2024, 1, 6, 17, 13, 21, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614533,
#   'longitude': -106.368348,
#   'elevation': 3100.1},
#  {'time': datetime.datetime(2024, 1, 6, 17, 13, 22, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614525,
#   'longitude': -106.368331,
#   'elevation': 3099.4},
#  {'time': datetime.datetime(2024, 1, 6, 17, 13, 23, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614516,
#   'longitude': -106.368313,
#   'elevation': 3099.4},
#  {'time': datetime.datetime(2024, 1, 6, 17, 13, 24, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.61451,
#   'longitude': -106.368301,
#   'elevation': 3100.0},
#  {'time': datetime.datetime(2024, 1, 6, 17, 13, 25, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614512,
#   'longitude': -106.368289,
#   'elevation': 3099.3},
#  {'time': datetime.datetime(2024, 1, 6, 17, 13, 26, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614509,
#   'longitude': -106.368282,
#   'elevation': 3099.3},
#  {'time': datetime.datetime(2024, 1, 6, 17, 13, 27, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614505,
#   'longitude': -106.368277,
#   'elevation': 3099.3},
#  {'time': datetime.datetime(2024, 1, 6, 17, 13, 28, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614498,
#   'longitude': -106.36828,
#   'elevation': 3099.3},
#  {'time': datetime.datetime(2024, 1, 6, 17, 13, 29, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614494,
#   'longitude': -106.368258,
#   'elevation': 3099.3},
#  {'time': datetime.datetime(2024, 1, 6, 17, 13, 30, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.61449,
#   'longitude': -106.368245,
#   'elevation': 3098.6},
#  {'time': datetime.datetime(2024, 1, 6, 17, 13, 31, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.61448,
#   'longitude': -106.368223,
#   'elevation': 3099.1},
#  {'time': datetime.datetime(2024, 1, 6, 17, 13, 32, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614472,
#   'longitude': -106.368213,
#   'elevation': 3099.1},
#  {'time': datetime.datetime(2024, 1, 6, 17, 13, 33, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614464,
#   'longitude': -106.368204,
#   'elevation': 3098.4},
#  {'time': datetime.datetime(2024, 1, 6, 17, 13, 34, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614449,
#   'longitude': -106.368193,
#   'elevation': 3098.8},
#  {'time': datetime.datetime(2024, 1, 6, 17, 13, 35, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614442,
#   'longitude': -106.368188,
#   'elevation': 3098.8},
#  {'time': datetime.datetime(2024, 1, 6, 17, 13, 36, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614435,
#   'longitude': -106.368183,
#   'elevation': 3098.8},
#  {'time': datetime.datetime(2024, 1, 6, 17, 13, 37, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614428,
#   'longitude': -106.368178,
#   'elevation': 3098.8},
#  {'time': datetime.datetime(2024, 1, 6, 17, 13, 38, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614418,
#   'longitude': -106.368159,
#   'elevation': 3098.0},
#  {'time': datetime.datetime(2024, 1, 6, 17, 13, 39, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614414,
#   'longitude': -106.368153,
#   'elevation': 3098.5},
#  {'time': datetime.datetime(2024, 1, 6, 17, 13, 40, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614411,
#   'longitude': -106.368146,
#   'elevation': 3098.5},
#  {'time': datetime.datetime(2024, 1, 6, 17, 13, 41, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614408,
#   'longitude': -106.36814,
#   'elevation': 3098.4},
#  {'time': datetime.datetime(2024, 1, 6, 17, 13, 42, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614405,
#   'longitude': -106.368133,
#   'elevation': 3098.4},
#  {'time': datetime.datetime(2024, 1, 6, 17, 13, 43, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614406,
#   'longitude': -106.368133,
#   'elevation': 3098.4},
#  {'time': datetime.datetime(2024, 1, 6, 17, 13, 44, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614387,
#   'longitude': -106.368107,
#   'elevation': 3097.6},
#  {'time': datetime.datetime(2024, 1, 6, 17, 13, 45, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614385,
#   'longitude': -106.368097,
#   'elevation': 3097.6},
#  {'time': datetime.datetime(2024, 1, 6, 17, 13, 46, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614381,
#   'longitude': -106.36807,
#   'elevation': 3097.2},
#  {'time': datetime.datetime(2024, 1, 6, 17, 13, 47, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.61438,
#   'longitude': -106.368061,
#   'elevation': 3097.1},
#  {'time': datetime.datetime(2024, 1, 6, 17, 13, 48, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614378,
#   'longitude': -106.368051,
#   'elevation': 3097.1},
#  {'time': datetime.datetime(2024, 1, 6, 17, 13, 49, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.61436,
#   'longitude': -106.368029,
#   'elevation': 3096.3},
#  {'time': datetime.datetime(2024, 1, 6, 17, 13, 50, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614356,
#   'longitude': -106.368023,
#   'elevation': 3096.3},
#  {'time': datetime.datetime(2024, 1, 6, 17, 13, 51, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614352,
#   'longitude': -106.368017,
#   'elevation': 3096.3},
#  {'time': datetime.datetime(2024, 1, 6, 17, 13, 52, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614342,
#   'longitude': -106.367995,
#   'elevation': 3095.8},
#  {'time': datetime.datetime(2024, 1, 6, 17, 13, 53, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614337,
#   'longitude': -106.367984,
#   'elevation': 3095.7},
#  {'time': datetime.datetime(2024, 1, 6, 17, 13, 54, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614333,
#   'longitude': -106.367973,
#   'elevation': 3095.7},
#  {'time': datetime.datetime(2024, 1, 6, 17, 13, 55, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614328,
#   'longitude': -106.367948,
#   'elevation': 3095.0},
#  {'time': datetime.datetime(2024, 1, 6, 17, 13, 56, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614326,
#   'longitude': -106.367937,
#   'elevation': 3095.0},
#  {'time': datetime.datetime(2024, 1, 6, 17, 13, 57, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614325,
#   'longitude': -106.367925,
#   'elevation': 3095.0},
#  {'time': datetime.datetime(2024, 1, 6, 17, 13, 58, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614316,
#   'longitude': -106.367905,
#   'elevation': 3094.5},
#  {'time': datetime.datetime(2024, 1, 6, 17, 13, 59, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.61431,
#   'longitude': -106.367895,
#   'elevation': 3094.5},
#  {'time': datetime.datetime(2024, 1, 6, 17, 14, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614305,
#   'longitude': -106.367886,
#   'elevation': 3094.5},
#  {'time': datetime.datetime(2024, 1, 6, 17, 14, 1, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614301,
#   'longitude': -106.367868,
#   'elevation': 3093.9},
#  {'time': datetime.datetime(2024, 1, 6, 17, 14, 2, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614298,
#   'longitude': -106.367846,
#   'elevation': 3093.9},
#  {'time': datetime.datetime(2024, 1, 6, 17, 14, 3, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614291,
#   'longitude': -106.367828,
#   'elevation': 3093.9},
#  {'time': datetime.datetime(2024, 1, 6, 17, 14, 4, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614279,
#   'longitude': -106.367813,
#   'elevation': 3093.6},
#  {'time': datetime.datetime(2024, 1, 6, 17, 14, 5, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614265,
#   'longitude': -106.367798,
#   'elevation': 3093.5},
#  {'time': datetime.datetime(2024, 1, 6, 17, 14, 6, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614267,
#   'longitude': -106.367787,
#   'elevation': 3093.5},
#  {'time': datetime.datetime(2024, 1, 6, 17, 14, 7, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614269,
#   'longitude': -106.367776,
#   'elevation': 3093.0},
#  {'time': datetime.datetime(2024, 1, 6, 17, 14, 8, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.61427,
#   'longitude': -106.367765,
#   'elevation': 3093.0},
#  {'time': datetime.datetime(2024, 1, 6, 17, 14, 9, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614275,
#   'longitude': -106.367744,
#   'elevation': 3093.0},
#  {'time': datetime.datetime(2024, 1, 6, 17, 14, 10, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614267,
#   'longitude': -106.367724,
#   'elevation': 3092.5},
#  {'time': datetime.datetime(2024, 1, 6, 17, 14, 11, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614269,
#   'longitude': -106.367727,
#   'elevation': 3092.5},
#  {'time': datetime.datetime(2024, 1, 6, 17, 14, 12, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614261,
#   'longitude': -106.367708,
#   'elevation': 3092.5},
#  {'time': datetime.datetime(2024, 1, 6, 17, 14, 13, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.61426,
#   'longitude': -106.367705,
#   'elevation': 3092.5},
#  {'time': datetime.datetime(2024, 1, 6, 17, 14, 14, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614257,
#   'longitude': -106.367686,
#   'elevation': 3092.0},
#  {'time': datetime.datetime(2024, 1, 6, 17, 14, 15, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614251,
#   'longitude': -106.36767,
#   'elevation': 3092.2},
#  {'time': datetime.datetime(2024, 1, 6, 17, 14, 17, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614249,
#   'longitude': -106.367661,
#   'elevation': 3092.2},
#  {'time': datetime.datetime(2024, 1, 6, 17, 14, 18, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614247,
#   'longitude': -106.367651,
#   'elevation': 3091.8},
#  {'time': datetime.datetime(2024, 1, 6, 17, 14, 19, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614244,
#   'longitude': -106.367642,
#   'elevation': 3091.8},
#  {'time': datetime.datetime(2024, 1, 6, 17, 14, 20, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614233,
#   'longitude': -106.367627,
#   'elevation': 3091.8},
#  {'time': datetime.datetime(2024, 1, 6, 17, 14, 21, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614236,
#   'longitude': -106.367626,
#   'elevation': 3091.8},
#  {'time': datetime.datetime(2024, 1, 6, 17, 14, 22, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.61423,
#   'longitude': -106.367613,
#   'elevation': 3091.7},
#  {'time': datetime.datetime(2024, 1, 6, 17, 14, 23, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614226,
#   'longitude': -106.367602,
#   'elevation': 3091.4},
#  {'time': datetime.datetime(2024, 1, 6, 17, 14, 24, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.61422,
#   'longitude': -106.367574,
#   'elevation': 3091.4},
#  {'time': datetime.datetime(2024, 1, 6, 17, 14, 25, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614221,
#   'longitude': -106.367564,
#   'elevation': 3091.0},
#  {'time': datetime.datetime(2024, 1, 6, 17, 14, 26, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614223,
#   'longitude': -106.367553,
#   'elevation': 3091.0},
#  {'time': datetime.datetime(2024, 1, 6, 17, 14, 27, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614218,
#   'longitude': -106.367537,
#   'elevation': 3091.3},
#  {'time': datetime.datetime(2024, 1, 6, 17, 14, 28, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614217,
#   'longitude': -106.367509,
#   'elevation': 3091.0},
#  {'time': datetime.datetime(2024, 1, 6, 17, 14, 29, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.61422,
#   'longitude': -106.367498,
#   'elevation': 3090.7},
#  {'time': datetime.datetime(2024, 1, 6, 17, 14, 30, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614219,
#   'longitude': -106.367484,
#   'elevation': 3090.7},
#  {'time': datetime.datetime(2024, 1, 6, 17, 14, 31, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.61422,
#   'longitude': -106.367487,
#   'elevation': 3090.7},
#  {'time': datetime.datetime(2024, 1, 6, 17, 14, 32, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614216,
#   'longitude': -106.367463,
#   'elevation': 3090.7},
#  {'time': datetime.datetime(2024, 1, 6, 17, 14, 33, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614228,
#   'longitude': -106.367459,
#   'elevation': 3090.3},
#  {'time': datetime.datetime(2024, 1, 6, 17, 14, 34, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614234,
#   'longitude': -106.367434,
#   'elevation': 3089.9},
#  {'time': datetime.datetime(2024, 1, 6, 17, 14, 35, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614233,
#   'longitude': -106.367407,
#   'elevation': 3089.9},
#  {'time': datetime.datetime(2024, 1, 6, 17, 14, 36, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614232,
#   'longitude': -106.367396,
#   'elevation': 3089.5},
#  {'time': datetime.datetime(2024, 1, 6, 17, 14, 37, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614232,
#   'longitude': -106.367386,
#   'elevation': 3089.5},
#  {'time': datetime.datetime(2024, 1, 6, 17, 14, 38, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614225,
#   'longitude': -106.367387,
#   'elevation': 3089.5},
#  {'time': datetime.datetime(2024, 1, 6, 17, 14, 39, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614226,
#   'longitude': -106.367385,
#   'elevation': 3089.5},
#  {'time': datetime.datetime(2024, 1, 6, 17, 14, 40, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614231,
#   'longitude': -106.367348,
#   'elevation': 3089.1},
#  {'time': datetime.datetime(2024, 1, 6, 17, 14, 41, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614228,
#   'longitude': -106.36732,
#   'elevation': 3089.1},
#  {'time': datetime.datetime(2024, 1, 6, 17, 14, 42, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614226,
#   'longitude': -106.36731,
#   'elevation': 3088.7},
#  {'time': datetime.datetime(2024, 1, 6, 17, 14, 43, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614225,
#   'longitude': -106.3673,
#   'elevation': 3088.7},
#  {'time': datetime.datetime(2024, 1, 6, 17, 14, 44, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614222,
#   'longitude': -106.367286,
#   'elevation': 3088.7},
#  {'time': datetime.datetime(2024, 1, 6, 17, 14, 45, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614223,
#   'longitude': -106.36727,
#   'elevation': 3088.7},
#  {'time': datetime.datetime(2024, 1, 6, 17, 14, 46, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614224,
#   'longitude': -106.367256,
#   'elevation': 3088.3},
#  {'time': datetime.datetime(2024, 1, 6, 17, 14, 47, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614224,
#   'longitude': -106.367237,
#   'elevation': 3088.3},
#  {'time': datetime.datetime(2024, 1, 6, 17, 14, 48, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614226,
#   'longitude': -106.367217,
#   'elevation': 3088.0},
#  {'time': datetime.datetime(2024, 1, 6, 17, 14, 49, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614229,
#   'longitude': -106.367206,
#   'elevation': 3088.0},
#  {'time': datetime.datetime(2024, 1, 6, 17, 14, 50, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614232,
#   'longitude': -106.367192,
#   'elevation': 3087.9},
#  {'time': datetime.datetime(2024, 1, 6, 17, 14, 51, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614235,
#   'longitude': -106.367174,
#   'elevation': 3087.6},
#  {'time': datetime.datetime(2024, 1, 6, 17, 14, 52, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614237,
#   'longitude': -106.367163,
#   'elevation': 3087.6},
#  {'time': datetime.datetime(2024, 1, 6, 17, 14, 53, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614239,
#   'longitude': -106.367146,
#   'elevation': 3087.6},
#  {'time': datetime.datetime(2024, 1, 6, 17, 14, 54, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614248,
#   'longitude': -106.367134,
#   'elevation': 3087.3},
#  {'time': datetime.datetime(2024, 1, 6, 17, 14, 55, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614248,
#   'longitude': -106.367122,
#   'elevation': 3087.3},
#  {'time': datetime.datetime(2024, 1, 6, 17, 14, 56, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614251,
#   'longitude': -106.367109,
#   'elevation': 3087.3},
#  {'time': datetime.datetime(2024, 1, 6, 17, 14, 57, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614256,
#   'longitude': -106.367098,
#   'elevation': 3086.8},
#  {'time': datetime.datetime(2024, 1, 6, 17, 14, 58, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614259,
#   'longitude': -106.367084,
#   'elevation': 3086.4},
#  {'time': datetime.datetime(2024, 1, 6, 17, 14, 59, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614262,
#   'longitude': -106.367075,
#   'elevation': 3086.4},
#  {'time': datetime.datetime(2024, 1, 6, 17, 15, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614266,
#   'longitude': -106.367062,
#   'elevation': 3086.4},
#  {'time': datetime.datetime(2024, 1, 6, 17, 15, 1, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614268,
#   'longitude': -106.367034,
#   'elevation': 3086.0},
#  {'time': datetime.datetime(2024, 1, 6, 17, 15, 2, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614269,
#   'longitude': -106.367024,
#   'elevation': 3086.0},
#  {'time': datetime.datetime(2024, 1, 6, 17, 15, 3, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.61427,
#   'longitude': -106.367015,
#   'elevation': 3086.0},
#  {'time': datetime.datetime(2024, 1, 6, 17, 15, 4, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614278,
#   'longitude': -106.366992,
#   'elevation': 3085.6},
#  {'time': datetime.datetime(2024, 1, 6, 17, 15, 5, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614283,
#   'longitude': -106.366982,
#   'elevation': 3085.6},
#  {'time': datetime.datetime(2024, 1, 6, 17, 15, 6, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614287,
#   'longitude': -106.366972,
#   'elevation': 3085.1},
#  {'time': datetime.datetime(2024, 1, 6, 17, 15, 7, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614292,
#   'longitude': -106.366955,
#   'elevation': 3084.7},
#  {'time': datetime.datetime(2024, 1, 6, 17, 15, 8, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614304,
#   'longitude': -106.366945,
#   'elevation': 3084.7},
#  {'time': datetime.datetime(2024, 1, 6, 17, 15, 9, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614309,
#   'longitude': -106.36694,
#   'elevation': 3084.7},
#  {'time': datetime.datetime(2024, 1, 6, 17, 15, 10, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614316,
#   'longitude': -106.366921,
#   'elevation': 3084.2},
#  {'time': datetime.datetime(2024, 1, 6, 17, 15, 11, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614318,
#   'longitude': -106.366913,
#   'elevation': 3083.7},
#  {'time': datetime.datetime(2024, 1, 6, 17, 15, 12, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.61432,
#   'longitude': -106.366905,
#   'elevation': 3083.7},
#  {'time': datetime.datetime(2024, 1, 6, 17, 15, 13, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614322,
#   'longitude': -106.366896,
#   'elevation': 3083.7},
#  {'time': datetime.datetime(2024, 1, 6, 17, 15, 14, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614337,
#   'longitude': -106.366865,
#   'elevation': 3083.2},
#  {'time': datetime.datetime(2024, 1, 6, 17, 15, 15, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614339,
#   'longitude': -106.366856,
#   'elevation': 3083.2},
#  {'time': datetime.datetime(2024, 1, 6, 17, 15, 16, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614342,
#   'longitude': -106.36684,
#   'elevation': 3083.2},
#  {'time': datetime.datetime(2024, 1, 6, 17, 15, 17, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614349,
#   'longitude': -106.366834,
#   'elevation': 3082.7},
#  {'time': datetime.datetime(2024, 1, 6, 17, 15, 18, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614352,
#   'longitude': -106.366814,
#   'elevation': 3082.1},
#  {'time': datetime.datetime(2024, 1, 6, 17, 15, 19, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614358,
#   'longitude': -106.366802,
#   'elevation': 3082.1},
#  {'time': datetime.datetime(2024, 1, 6, 17, 15, 20, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614361,
#   'longitude': -106.366792,
#   'elevation': 3081.6},
#  {'time': datetime.datetime(2024, 1, 6, 17, 15, 21, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614364,
#   'longitude': -106.366786,
#   'elevation': 3081.6},
#  {'time': datetime.datetime(2024, 1, 6, 17, 15, 22, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614369,
#   'longitude': -106.366775,
#   'elevation': 3081.6},
#  {'time': datetime.datetime(2024, 1, 6, 17, 15, 23, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614362,
#   'longitude': -106.366771,
#   'elevation': 3081.6},
#  {'time': datetime.datetime(2024, 1, 6, 17, 15, 24, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614361,
#   'longitude': -106.366767,
#   'elevation': 3081.6},
#  {'time': datetime.datetime(2024, 1, 6, 17, 15, 25, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.61436,
#   'longitude': -106.366764,
#   'elevation': 3081.6},
#  {'time': datetime.datetime(2024, 1, 6, 17, 15, 26, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614361,
#   'longitude': -106.366759,
#   'elevation': 3081.6},
#  {'time': datetime.datetime(2024, 1, 6, 17, 15, 27, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614365,
#   'longitude': -106.366752,
#   'elevation': 3081.3},
#  {'time': datetime.datetime(2024, 1, 6, 17, 15, 28, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614359,
#   'longitude': -106.366761,
#   'elevation': 3081.5},
#  {'time': datetime.datetime(2024, 1, 6, 17, 15, 29, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614361,
#   'longitude': -106.366766,
#   'elevation': 3081.5},
#  {'time': datetime.datetime(2024, 1, 6, 17, 15, 30, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614353,
#   'longitude': -106.366755,
#   'elevation': 3081.5},
#  {'time': datetime.datetime(2024, 1, 6, 17, 15, 31, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614354,
#   'longitude': -106.366754,
#   'elevation': 3081.5},
#  {'time': datetime.datetime(2024, 1, 6, 17, 15, 32, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614354,
#   'longitude': -106.36676,
#   'elevation': 3081.5},
#  {'time': datetime.datetime(2024, 1, 6, 17, 15, 33, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614353,
# ...
#   'longitude': -106.365785,
#   'elevation': 3076.1},
#  {'time': datetime.datetime(2024, 1, 6, 17, 25, 16, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614638,
#   'longitude': -106.365783,
#   'elevation': 3076.1},
#  {'time': datetime.datetime(2024, 1, 6, 17, 25, 17, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614638,
#   'longitude': -106.365782,
#   'elevation': 3076.0},
#  {'time': datetime.datetime(2024, 1, 6, 17, 25, 18, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614638,
#   'longitude': -106.36578,
#   'elevation': 3076.0},
#  {'time': datetime.datetime(2024, 1, 6, 17, 25, 19, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614637,
#   'longitude': -106.365778,
#   'elevation': 3076.0},
#  {'time': datetime.datetime(2024, 1, 6, 17, 25, 20, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614637,
#   'longitude': -106.365776,
#   'elevation': 3076.0},
#  {'time': datetime.datetime(2024, 1, 6, 17, 25, 21, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614637,
#   'longitude': -106.365775,
#   'elevation': 3076.0},
#  {'time': datetime.datetime(2024, 1, 6, 17, 25, 22, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614636,
#   'longitude': -106.365773,
#   'elevation': 3076.0},
#  {'time': datetime.datetime(2024, 1, 6, 17, 25, 23, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614636,
#   'longitude': -106.365771,
#   'elevation': 3076.0},
#  {'time': datetime.datetime(2024, 1, 6, 17, 25, 24, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614636,
#   'longitude': -106.36577,
#   'elevation': 3076.0},
#  {'time': datetime.datetime(2024, 1, 6, 17, 25, 25, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614635,
#   'longitude': -106.365768,
#   'elevation': 3076.0},
#  {'time': datetime.datetime(2024, 1, 6, 17, 25, 26, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614635,
#   'longitude': -106.365766,
#   'elevation': 3075.9},
#  {'time': datetime.datetime(2024, 1, 6, 17, 25, 27, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614635,
#   'longitude': -106.365765,
#   'elevation': 3075.9},
#  {'time': datetime.datetime(2024, 1, 6, 17, 25, 28, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614634,
#   'longitude': -106.365763,
#   'elevation': 3075.9},
#  {'time': datetime.datetime(2024, 1, 6, 17, 25, 29, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614634,
#   'longitude': -106.365761,
#   'elevation': 3075.9},
#  {'time': datetime.datetime(2024, 1, 6, 17, 25, 30, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614634,
#   'longitude': -106.365759,
#   'elevation': 3075.9},
#  {'time': datetime.datetime(2024, 1, 6, 17, 25, 31, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614633,
#   'longitude': -106.365758,
#   'elevation': 3075.9},
#  {'time': datetime.datetime(2024, 1, 6, 17, 25, 32, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614633,
#   'longitude': -106.365756,
#   'elevation': 3075.9},
#  {'time': datetime.datetime(2024, 1, 6, 17, 25, 33, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614633,
#   'longitude': -106.365754,
#   'elevation': 3075.9},
#  {'time': datetime.datetime(2024, 1, 6, 17, 25, 34, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614632,
#   'longitude': -106.365753,
#   'elevation': 3075.9},
#  {'time': datetime.datetime(2024, 1, 6, 17, 25, 35, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614632,
#   'longitude': -106.365751,
#   'elevation': 3075.9},
#  {'time': datetime.datetime(2024, 1, 6, 17, 25, 36, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614632,
#   'longitude': -106.365749,
#   'elevation': 3075.9},
#  {'time': datetime.datetime(2024, 1, 6, 17, 25, 37, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614631,
#   'longitude': -106.365747,
#   'elevation': 3075.8},
#  {'time': datetime.datetime(2024, 1, 6, 17, 25, 38, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614631,
#   'longitude': -106.365746,
#   'elevation': 3075.8},
#  {'time': datetime.datetime(2024, 1, 6, 17, 25, 39, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614631,
#   'longitude': -106.365744,
#   'elevation': 3075.8},
#  {'time': datetime.datetime(2024, 1, 6, 17, 25, 40, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.61463,
#   'longitude': -106.365742,
#   'elevation': 3075.8},
#  {'time': datetime.datetime(2024, 1, 6, 17, 25, 41, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.61463,
#   'longitude': -106.365741,
#   'elevation': 3075.8},
#  {'time': datetime.datetime(2024, 1, 6, 17, 25, 42, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.61463,
#   'longitude': -106.365739,
#   'elevation': 3075.8},
#  {'time': datetime.datetime(2024, 1, 6, 17, 25, 43, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614629,
#   'longitude': -106.365737,
#   'elevation': 3075.8},
#  {'time': datetime.datetime(2024, 1, 6, 17, 25, 44, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614629,
#   'longitude': -106.365736,
#   'elevation': 3075.8},
#  {'time': datetime.datetime(2024, 1, 6, 17, 25, 45, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614629,
#   'longitude': -106.365734,
#   'elevation': 3075.8},
#  {'time': datetime.datetime(2024, 1, 6, 17, 25, 46, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614628,
#   'longitude': -106.365732,
#   'elevation': 3075.8},
#  {'time': datetime.datetime(2024, 1, 6, 17, 25, 47, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614628,
#   'longitude': -106.36573,
#   'elevation': 3075.8},
#  {'time': datetime.datetime(2024, 1, 6, 17, 25, 48, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614628,
#   'longitude': -106.365729,
#   'elevation': 3075.8},
#  {'time': datetime.datetime(2024, 1, 6, 17, 25, 49, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614627,
#   'longitude': -106.365727,
#   'elevation': 3075.8},
#  {'time': datetime.datetime(2024, 1, 6, 17, 25, 50, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614625,
#   'longitude': -106.365726,
#   'elevation': 3075.7},
#  {'time': datetime.datetime(2024, 1, 6, 17, 25, 51, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614628,
#   'longitude': -106.36573,
#   'elevation': 3075.7},
#  {'time': datetime.datetime(2024, 1, 6, 17, 25, 52, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.61463,
#   'longitude': -106.365729,
#   'elevation': 3075.7},
#  {'time': datetime.datetime(2024, 1, 6, 17, 25, 53, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614639,
#   'longitude': -106.365736,
#   'elevation': 3075.7},
#  {'time': datetime.datetime(2024, 1, 6, 17, 25, 54, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614642,
#   'longitude': -106.36574,
#   'elevation': 3075.7},
#  {'time': datetime.datetime(2024, 1, 6, 17, 25, 55, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614643,
#   'longitude': -106.365759,
#   'elevation': 3075.7},
#  {'time': datetime.datetime(2024, 1, 6, 17, 25, 56, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614638,
#   'longitude': -106.365768,
#   'elevation': 3075.7},
#  {'time': datetime.datetime(2024, 1, 6, 17, 25, 57, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614632,
#   'longitude': -106.365776,
#   'elevation': 3075.7},
#  {'time': datetime.datetime(2024, 1, 6, 17, 25, 58, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614635,
#   'longitude': -106.365771,
#   'elevation': 3075.7},
#  {'time': datetime.datetime(2024, 1, 6, 17, 25, 59, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614631,
#   'longitude': -106.365767,
#   'elevation': 3075.7},
#  {'time': datetime.datetime(2024, 1, 6, 17, 26, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614628,
#   'longitude': -106.365765,
#   'elevation': 3075.7},
#  {'time': datetime.datetime(2024, 1, 6, 17, 26, 1, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614635,
#   'longitude': -106.365762,
#   'elevation': 3075.7},
#  {'time': datetime.datetime(2024, 1, 6, 17, 26, 2, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614632,
#   'longitude': -106.365763,
#   'elevation': 3075.7},
#  {'time': datetime.datetime(2024, 1, 6, 17, 26, 3, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614632,
#   'longitude': -106.365762,
#   'elevation': 3075.6},
#  {'time': datetime.datetime(2024, 1, 6, 17, 26, 4, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614632,
#   'longitude': -106.365762,
#   'elevation': 3075.6},
#  {'time': datetime.datetime(2024, 1, 6, 17, 26, 5, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614623,
#   'longitude': -106.365772,
#   'elevation': 3075.7},
#  {'time': datetime.datetime(2024, 1, 6, 17, 26, 6, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.61462,
#   'longitude': -106.365776,
#   'elevation': 3075.7},
#  {'time': datetime.datetime(2024, 1, 6, 17, 26, 7, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614617,
#   'longitude': -106.365777,
#   'elevation': 3075.7},
#  {'time': datetime.datetime(2024, 1, 6, 17, 26, 8, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614608,
#   'longitude': -106.365772,
#   'elevation': 3076.5},
#  {'time': datetime.datetime(2024, 1, 6, 17, 26, 9, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614603,
#   'longitude': -106.365773,
#   'elevation': 3076.4},
#  {'time': datetime.datetime(2024, 1, 6, 17, 26, 10, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614602,
#   'longitude': -106.365779,
#   'elevation': 3076.4},
#  {'time': datetime.datetime(2024, 1, 6, 17, 26, 11, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614605,
#   'longitude': -106.365773,
#   'elevation': 3076.4},
#  {'time': datetime.datetime(2024, 1, 6, 17, 26, 12, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614603,
#   'longitude': -106.36577,
#   'elevation': 3076.4},
#  {'time': datetime.datetime(2024, 1, 6, 17, 26, 13, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614605,
#   'longitude': -106.365768,
#   'elevation': 3076.4},
#  {'time': datetime.datetime(2024, 1, 6, 17, 26, 14, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614604,
#   'longitude': -106.365749,
#   'elevation': 3076.3},
#  {'time': datetime.datetime(2024, 1, 6, 17, 26, 15, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614609,
#   'longitude': -106.365754,
#   'elevation': 3076.3},
#  {'time': datetime.datetime(2024, 1, 6, 17, 26, 16, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614613,
#   'longitude': -106.365755,
#   'elevation': 3076.3},
#  {'time': datetime.datetime(2024, 1, 6, 17, 26, 17, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614619,
#   'longitude': -106.365751,
#   'elevation': 3075.5},
#  {'time': datetime.datetime(2024, 1, 6, 17, 26, 18, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614616,
#   'longitude': -106.365744,
#   'elevation': 3075.5},
#  {'time': datetime.datetime(2024, 1, 6, 17, 26, 19, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614616,
#   'longitude': -106.365734,
#   'elevation': 3075.5},
#  {'time': datetime.datetime(2024, 1, 6, 17, 26, 20, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614605,
#   'longitude': -106.36573,
#   'elevation': 3076.3},
#  {'time': datetime.datetime(2024, 1, 6, 17, 26, 21, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614583,
#   'longitude': -106.365734,
#   'elevation': 3076.3},
#  {'time': datetime.datetime(2024, 1, 6, 17, 26, 22, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.61458,
#   'longitude': -106.36573,
#   'elevation': 3077.1},
#  {'time': datetime.datetime(2024, 1, 6, 17, 26, 23, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614565,
#   'longitude': -106.365717,
#   'elevation': 3077.0},
#  {'time': datetime.datetime(2024, 1, 6, 17, 26, 24, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614575,
#   'longitude': -106.36573,
#   'elevation': 3077.1},
#  {'time': datetime.datetime(2024, 1, 6, 17, 26, 25, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.61457,
#   'longitude': -106.365728,
#   'elevation': 3077.1},
#  {'time': datetime.datetime(2024, 1, 6, 17, 26, 26, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614559,
#   'longitude': -106.365718,
#   'elevation': 3077.0},
#  {'time': datetime.datetime(2024, 1, 6, 17, 26, 27, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614545,
#   'longitude': -106.365712,
#   'elevation': 3077.8},
#  {'time': datetime.datetime(2024, 1, 6, 17, 26, 28, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614535,
#   'longitude': -106.365698,
#   'elevation': 3077.8},
#  {'time': datetime.datetime(2024, 1, 6, 17, 26, 29, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614516,
#   'longitude': -106.365695,
#   'elevation': 3077.8},
#  {'time': datetime.datetime(2024, 1, 6, 17, 26, 30, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614508,
#   'longitude': -106.365703,
#   'elevation': 3078.7},
#  {'time': datetime.datetime(2024, 1, 6, 17, 26, 31, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614499,
#   'longitude': -106.365711,
#   'elevation': 3078.7},
#  {'time': datetime.datetime(2024, 1, 6, 17, 26, 32, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614491,
#   'longitude': -106.365719,
#   'elevation': 3078.7},
#  {'time': datetime.datetime(2024, 1, 6, 17, 26, 33, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614483,
#   'longitude': -106.365727,
#   'elevation': 3078.7},
#  {'time': datetime.datetime(2024, 1, 6, 17, 26, 34, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614416,
#   'longitude': -106.365707,
#   'elevation': 3081.6},
#  {'time': datetime.datetime(2024, 1, 6, 17, 26, 35, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614353,
#   'longitude': -106.365586,
#   'elevation': 3083.4},
#  {'time': datetime.datetime(2024, 1, 6, 17, 26, 36, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614322,
#   'longitude': -106.365549,
#   'elevation': 3084.7},
#  {'time': datetime.datetime(2024, 1, 6, 17, 26, 37, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614283,
#   'longitude': -106.365504,
#   'elevation': 3086.4},
#  {'time': datetime.datetime(2024, 1, 6, 17, 26, 38, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614239,
#   'longitude': -106.365462,
#   'elevation': 3087.0},
#  {'time': datetime.datetime(2024, 1, 6, 17, 26, 39, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614214,
#   'longitude': -106.365439,
#   'elevation': 3087.4},
#  {'time': datetime.datetime(2024, 1, 6, 17, 26, 40, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.61418,
#   'longitude': -106.365405,
#   'elevation': 3088.1},
#  {'time': datetime.datetime(2024, 1, 6, 17, 26, 41, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614143,
#   'longitude': -106.365366,
#   'elevation': 3088.9},
#  {'time': datetime.datetime(2024, 1, 6, 17, 26, 42, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614109,
#   'longitude': -106.365338,
#   'elevation': 3089.7},
#  {'time': datetime.datetime(2024, 1, 6, 17, 26, 43, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614079,
#   'longitude': -106.36531,
#   'elevation': 3090.5},
#  {'time': datetime.datetime(2024, 1, 6, 17, 26, 44, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614046,
#   'longitude': -106.365281,
#   'elevation': 3091.3},
#  {'time': datetime.datetime(2024, 1, 6, 17, 26, 45, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.614014,
#   'longitude': -106.365247,
#   'elevation': 3092.2},
#  {'time': datetime.datetime(2024, 1, 6, 17, 26, 46, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.613983,
#   'longitude': -106.36522,
#   'elevation': 3093.1},
#  {'time': datetime.datetime(2024, 1, 6, 17, 26, 47, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.613948,
#   'longitude': -106.365192,
#   'elevation': 3094.1},
#  {'time': datetime.datetime(2024, 1, 6, 17, 26, 48, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.613917,
#   'longitude': -106.365164,
#   'elevation': 3095.0},
#  {'time': datetime.datetime(2024, 1, 6, 17, 26, 49, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.613887,
#   'longitude': -106.365129,
#   'elevation': 3096.0},
#  {'time': datetime.datetime(2024, 1, 6, 17, 26, 50, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.613857,
#   'longitude': -106.365098,
#   'elevation': 3097.1},
#  {'time': datetime.datetime(2024, 1, 6, 17, 26, 51, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.613826,
#   'longitude': -106.365071,
#   'elevation': 3098.1},
#  {'time': datetime.datetime(2024, 1, 6, 17, 26, 53, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.613792,
#   'longitude': -106.365036,
#   'elevation': 3099.3},
#  {'time': datetime.datetime(2024, 1, 6, 17, 26, 54, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.613758,
#   'longitude': -106.365004,
#   'elevation': 3100.5},
#  {'time': datetime.datetime(2024, 1, 6, 17, 26, 55, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.61373,
#   'longitude': -106.364974,
#   'elevation': 3101.6},
#  {'time': datetime.datetime(2024, 1, 6, 17, 26, 56, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.613699,
#   'longitude': -106.364947,
#   'elevation': 3102.6},
#  {'time': datetime.datetime(2024, 1, 6, 17, 26, 57, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.613666,
#   'longitude': -106.364915,
#   'elevation': 3103.8},
#  {'time': datetime.datetime(2024, 1, 6, 17, 26, 58, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.613639,
#   'longitude': -106.364888,
#   'elevation': 3104.7},
#  {'time': datetime.datetime(2024, 1, 6, 17, 26, 59, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.613611,
#   'longitude': -106.36486,
#   'elevation': 3105.7},
#  {'time': datetime.datetime(2024, 1, 6, 17, 27, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.613576,
#   'longitude': -106.364829,
#   'elevation': 3106.8},
#  {'time': datetime.datetime(2024, 1, 6, 17, 27, 1, tzinfo=SimpleTZ('Z')),
#   'latitude': 39.613536,
#   'longitude': -106.364797,
#   'elevation': 3108.0},
#  ...]

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[35], line 4
#       2 data = {'data': points}
#       3 with open('pow_day_at_vail.json', 'w') as f:
# ----> 4     json.dump(data, f)
#
# File /opt/homebrew/Cellar/python@3.11/3.11.5/Frameworks/Python.framework/Versions/3.11/lib/python3.11/json/__init__.py:179, in dump(obj, fp, skipkeys, ensure_ascii, check_circular, allow_nan, cls, indent, separators, default, sort_keys, **kw)
#     173     iterable = cls(skipkeys=skipkeys, ensure_ascii=ensure_ascii,
#     174         check_circular=check_circular, allow_nan=allow_nan, indent=indent,
#     175         separators=separators,
#     176         default=default, sort_keys=sort_keys, **kw).iterencode(obj)
#     177 # could accelerate with writelines in some versions of Python, at
#     178 # a debuggability cost
# --> 179 for chunk in iterable:
#     180     fp.write(chunk)
#
# File /opt/homebrew/Cellar/python@3.11/3.11.5/Frameworks/Python.framework/Versions/3.11/lib/python3.11/json/encoder.py:432, in _make_iterencode.<locals>._iterencode(o, _current_indent_level)
#     430     yield from _iterencode_list(o, _current_indent_level)
#     431 elif isinstance(o, dict):
# --> 432     yield from _iterencode_dict(o, _current_indent_level)
#     433 else:
#     434     if markers is not None:
#
# File /opt/homebrew/Cellar/python@3.11/3.11.5/Frameworks/Python.framework/Versions/3.11/lib/python3.11/json/encoder.py:406, in _make_iterencode.<locals>._iterencode_dict(dct, _current_indent_level)
#     404         else:
#     405             chunks = _iterencode(value, _current_indent_level)
# --> 406         yield from chunks
#     407 if newline_indent is not None:
#     408     _current_indent_level -= 1
#
# File /opt/homebrew/Cellar/python@3.11/3.11.5/Frameworks/Python.framework/Versions/3.11/lib/python3.11/json/encoder.py:326, in _make_iterencode.<locals>._iterencode_list(lst, _current_indent_level)
#     324         else:
#     325             chunks = _iterencode(value, _current_indent_level)
# --> 326         yield from chunks
#     327 if newline_indent is not None:
#     328     _current_indent_level -= 1
#
# File /opt/homebrew/Cellar/python@3.11/3.11.5/Frameworks/Python.framework/Versions/3.11/lib/python3.11/json/encoder.py:406, in _make_iterencode.<locals>._iterencode_dict(dct, _current_indent_level)
#     404         else:
#     405             chunks = _iterencode(value, _current_indent_level)
# --> 406         yield from chunks
#     407 if newline_indent is not None:
#     408     _current_indent_level -= 1
#
# File /opt/homebrew/Cellar/python@3.11/3.11.5/Frameworks/Python.framework/Versions/3.11/lib/python3.11/json/encoder.py:439, in _make_iterencode.<locals>._iterencode(o, _current_indent_level)
#     437         raise ValueError("Circular reference detected")
#     438     markers[markerid] = o
# --> 439 o = _default(o)
#     440 yield from _iterencode(o, _current_indent_level)
#     441 if markers is not None:
#
# File /opt/homebrew/Cellar/python@3.11/3.11.5/Frameworks/Python.framework/Versions/3.11/lib/python3.11/json/encoder.py:180, in JSONEncoder.default(self, o)
#     161 def default(self, o):
#     162     """Implement this method in a subclass such that it returns
#     163     a serializable object for ``o``, or calls the base implementation
#     164     (to raise a ``TypeError``).
#    (...)
#     178
#     179     """
# --> 180     raise TypeError(f'Object of type {o.__class__.__name__} '
#     181                     f'is not JSON serializable')
#
# TypeError: Object of type datetime is not JSON serializable

# %%
import json
data = {'data': points}
with open('pow_day_at_vail.json', 'w') as f:
    json.dump(data, f)
